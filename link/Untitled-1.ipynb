# %%
with open(r'C:\Users\user\OneDrive\桌面\gistfile1.txt', 'r') as f:
    l = list(map(int, f.read().split()))
    print(max(l))
    print(min(l))
    print(sum(l))
    print(len(l))
# Out:
# 999999607
# 38
# 399956772635708
# 799617

# %%
print("max: 999999607")
print("min: 38")
print("sum: 399956772635708")
print("count: 799617")
# Out:
# 999999607
# 38
# 399956772635708
# 799617
